# %%
import pandas as pd
import numpy as np

# %%
# En primer lugar importamos nuestro documento.

basket=pd.read_csv("./input/basket_stats.csv")

# %%
# Vamos a comprobar ahora los datos de nuestra base de datos.

basket
# Out:
#                       League       Season           Stage  \
# 0                        NBA  2009 - 2010  Regular_Season
# 1                        NBA  2009 - 2010  Regular_Season
# 2                        NBA  2009 - 2010  Regular_Season
# 3                        NBA  2009 - 2010  Regular_Season
# 4                        NBA  2009 - 2010  Regular_Season
# ...                      ...          ...             ...
# 44061  Ukrainian-Superleague  2019 - 2020   International
# 44062  Ukrainian-Superleague  2019 - 2020   International
# 44063  Ukrainian-Superleague  2019 - 2020   International
# 44064  Ukrainian-Superleague  2019 - 2020   International
# 44065  Ukrainian-Superleague  2019 - 2020   International
#
#                     Player  Team  GP     MIN  FGM   FGA  3PM  ...   PTS  \
# 0             Kevin Durant   OKC  82  3239.3  794  1668  128  ...  2472
# 1             LeBron James   CLE  76  2965.6  768  1528  129  ...  2258
# ...

# %%
# Vamos a ver ahora que columnas de datos tenemos.

basket.columns
# Out:
# Index(['League', 'Season', 'Stage', 'Player', 'Team', 'GP', 'MIN', 'FGM',
#        'FGA', '3PM', '3PA', 'FTM', 'FTA', 'TOV', 'PF', 'ORB', 'DRB', 'REB',
#        'AST', 'STL', 'BLK', 'PTS', 'birth_year', 'birth_month', 'birth_date',
#        'height', 'height_cm', 'weight', 'weight_kg', 'nationality',
#        'high_school'],
#       dtype='object')

# %%
# Seleccionamos las columnas que vamos a utilizar a ver ahora que columnas de datos tenemos.

basket1=basket[['League', 'Season', 'Stage', 'Player', 'Team', 'GP', 'MIN', 'FGM',
       'FGA', '3PM', '3PA', 'FTM', 'FTA', 'TOV', 'PF', 'ORB', 'DRB', 'REB',
       'AST', 'STL', 'BLK', 'PTS']]

# %%
# Vamos a renombrar algunas características para hacerlas más entendibles.

basket1.columns=['League', 'Season', 'Stage', 'Player', 'Team', 'GP', 'MIN', '2PM',
       '2PA', '3PM', '3PA', '1PM', '1PA', 'TOV', 'PF', 'ORB', 'DRB', 'REB',
       'AST', 'STL', 'BLK', 'PTS']

# %%
# Vamos a seleccionar ahora unicamente la NBA, ya que nuestro cliente pertenece a dicha liga.

basket2=basket1[basket1["League"]=="NBA"]

# %%
#Vamos a seleccionar sólo la fase de liga regular.

basket3=basket2[basket2["Stage"]=="Regular_Season"]

# %%
# Seleccionamos ahora la última temporada.

basket4=basket3[basket3["Season"]=="2018 - 2019"]

# %%
# Seleccionamos ahora el equipo de nuestro cliente "Los Angeles Lakers" y al actual campeón de la NBA.
# El actual equipo de la NBA son los Toronto Raptors, los cuales ya utilizan ánalisis de datos para mejorar sis stats.

basket5=basket4[basket4["Team"]=="LAL"]
basket6=basket4[basket4["Team"]=="TOR"]
basket7=pd.concat([basket5, basket6], axis=0)

# %%
# Vamos a comprobar ahora que no tengamos filas duplicadas.

basket7[basket7.duplicated()]==True
# Out:
# Empty DataFrame
# Columns: [League, Season, Stage, Player, Team, GP, MIN, 2PM, 2PA, 3PM, 3PA, 1PM, 1PA, TOV, PF, ORB, DRB, REB, AST, STL, BLK, PTS]
# Index: []
#
# [0 rows x 22 columns]

# %%
# No tenemos filas duplicadas, por lo que vamos a comprobar ahora si tenemos valores nulos.

basket7.isnull().sum()
# Out:
# League    0
# Season    0
# Stage     0
# Player    0
# Team      0
# GP        0
# MIN       0
# 2PM       0
# 2PA       0
# 3PM       0
# 3PA       0
# 1PM       0
# 1PA       0
# TOV       0
# PF        0
# ORB       0
# DRB       0
# REB       0
# AST       0
# STL       0
# BLK       0
# PTS       0
# dtype: int64

# %%
# Vamos a utilizar la función regex para modificar los nombres de los equipos y hacerlos más entendibles.

basket7.Team=basket7.Team.str.replace(r" ?LAL ?", "Lakers")
basket7.Team=basket7.Team.str.replace(r" ?TOR ?", "Toronto Raptors")

# %%
# Tampoco tenemos valores nulos, por lo que finalmente, está será la tabla que analizaremos.

basket7.reset_index()
# Out:
#     index League       Season           Stage                    Player  \
# 0    2061    NBA  2018 - 2019  Regular_Season              LeBron James
# 1    2081    NBA  2018 - 2019  Regular_Season                Kyle Kuzma
# 2    2122    NBA  2018 - 2019  Regular_Season            Brandon Ingram
# 3    2126    NBA  2018 - 2019  Regular_Season  Kentavious Caldwell-Pope
# 4    2137    NBA  2018 - 2019  Regular_Season              JaVale McGee
# 5    2175    NBA  2018 - 2019  Regular_Season            Reggie Bullock
# 6    2230    NBA  2018 - 2019  Regular_Season                 Josh Hart
# 7    2243    NBA  2018 - 2019  Regular_Season          Lance Stephenson
# 8    2254    NBA  2018 - 2019  Regular_Season                Lonzo Ball
# 9    2265    NBA  2018 - 2019  Regular_Season              Mike Muscala
# 10   2316    NBA  2018 - 2019  Regular_Season            Tyson Chandler
# 11   2057    NBA  2018 - 2019  Regular_Season             Kawhi Leonard
# ...

# %%
# Exportamos finalmente nuestra nueva tabla.

basket7.to_csv(r"./output/basket_analysis.csv", index=False)

# %%
# Vamos a sacar también una tabla que contenga a todos los equipos de la NBA durante la temporada 2018-2019.
# Esta tabla la vamos a utilizar en el jupyter de funciones.
# Vamos a comprobar ahora si tenemos valores duplicados en esta tabla.

basket4[basket4.duplicated()]==True
# Out:
# Empty DataFrame
# Columns: [League, Season, Stage, Player, Team, GP, MIN, 2PM, 2PA, 3PM, 3PA, 1PM, 1PA, TOV, PF, ORB, DRB, REB, AST, STL, BLK, PTS]
# Index: []
#
# [0 rows x 22 columns]

# %%
# No tenemos filas duplicadas, vamos a comprobar ahora si existen valores nulos.

basket4.isnull().sum()
# Out:
# League    0
# Season    0
# Stage     0
# Player    0
# Team      0
# GP        0
# MIN       0
# 2PM       0
# 2PA       0
# 3PM       0
# 3PA       0
# 1PM       0
# 1PA       0
# TOV       0
# PF        0
# ORB       0
# DRB       0
# REB       0
# AST       0
# STL       0
# BLK       0
# PTS       0
# dtype: int64

# %%
# Exportamos finalmente nuestra nueva tabla.

basket4.to_csv(r"./output/basket_functions.csv", index=False)
