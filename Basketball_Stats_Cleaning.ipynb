# %%
import pandas as pd
import numpy as np

# %%
# En primer lugar importamos nuestro documento.

basket=pd.read_csv("./input/basket_stats.csv")

# %%
# Vamos a comprobar ahora los datos de nuestra base de datos.

basket
# Out:
#                       League       Season           Stage  \
# 0                        NBA  2009 - 2010  Regular_Season
# 1                        NBA  2009 - 2010  Regular_Season
# 2                        NBA  2009 - 2010  Regular_Season
# 3                        NBA  2009 - 2010  Regular_Season
# 4                        NBA  2009 - 2010  Regular_Season
# ...                      ...          ...             ...
# 44061  Ukrainian-Superleague  2019 - 2020   International
# 44062  Ukrainian-Superleague  2019 - 2020   International
# 44063  Ukrainian-Superleague  2019 - 2020   International
# 44064  Ukrainian-Superleague  2019 - 2020   International
# 44065  Ukrainian-Superleague  2019 - 2020   International
#
#                     Player  Team  GP     MIN  FGM   FGA  3PM  ...   PTS  \
# 0             Kevin Durant   OKC  82  3239.3  794  1668  128  ...  2472
# 1             LeBron James   CLE  76  2965.6  768  1528  129  ...  2258
# 2              Dwyane Wade   MIA  77  2792.4  719  1511   73  ...  2045
# 3            Dirk Nowitzki   DAL  81  3038.8  720  1496   51  ...  2027
# 4              Kobe Bryant   LAL  73  2835.4  716  1569   99  ...  1970
# ...                    ...   ...  ..     ...  ...   ...  ...  ...   ...
# 44061  Kyrylo Meshheryakov   MYK  15   127.0    7    28    2  ...    19
# 44062    Yaroslav Kadygrob   ODE  10    81.7    5    16    4  ...    15
# 44063      Ernesto Tkachuk   ODE  16   124.7    1    15    0  ...     9
# 44064    Andrij Shapovalov  KHAR  12    59.2    0     8    0  ...     3
# 44065    Dmitriy Lypovtsev  KHAR   5    86.3    1    13    0  ...     2
#
#        birth_year  birth_month    birth_date  height  height_cm  weight  \
# 0          1988.0          Sep  Sep 29, 1988  06-Sep      206.0   240.0
# 1          1984.0          Dec  Dec 30, 1984  06-Aug      203.0   250.0
# 2          1982.0          Jan  Jan 17, 1982  06-Apr      193.0   220.0
# 3          1978.0          Jun  Jun 19, 1978     7-0      213.0   245.0
# 4          1978.0          Aug  Aug 23, 1978  06-Jun      198.0   212.0
# ...           ...          ...           ...     ...        ...     ...
# 44061      1995.0          Aug  Aug 17, 1995  06-Jun      198.0   182.0
# 44062      1991.0          Oct  Oct 28, 1991  06-Mar      191.0   187.0
# 44063      1994.0          Sep  Sep 17, 1994  06-Feb      188.0   200.0
# 44064      1993.0          Nov  Nov 10, 1993  06-Feb      188.0   171.0
# 44065      1986.0          Oct  Oct 10, 1986  06-Aug      203.0   220.0
#
#        weight_kg    nationality                       high_school
# 0          109.0  United States         Montrose Christian School
# 1          113.0  United States  St. Vincent St. Mary High School
# 2          100.0  United States    Harold L. Richards High School
# 3          111.0        Germany                               NaN
# 4           96.0  United States          Lower Merion High School
# ...          ...            ...                               ...
# 44061       83.0        Ukraine                               NaN
# 44062       85.0        Ukraine                               NaN
# 44063       91.0        Ukraine                               NaN
# 44064       78.0        Ukraine                               NaN
# 44065      100.0        Ukraine                               NaN
#
# [44066 rows x 31 columns]

# %%
# Vamos a ver ahora que columnas de datos tenemos.

basket.columns
# Out:
# Index(['League', 'Season', 'Stage', 'Player', 'Team', 'GP', 'MIN', 'FGM',
#        'FGA', '3PM', '3PA', 'FTM', 'FTA', 'TOV', 'PF', 'ORB', 'DRB', 'REB',
#        'AST', 'STL', 'BLK', 'PTS', 'birth_year', 'birth_month', 'birth_date',
#        'height', 'height_cm', 'weight', 'weight_kg', 'nationality',
#        'high_school'],
#       dtype='object')

# %%
# Seleccionamos las columnas que vamos a utilizar a ver ahora que columnas de datos tenemos.

basket1=basket[['League', 'Season', 'Player', 'Team', 'GP', 'MIN', 'FGM',
       'FGA', '3PM', '3PA', 'FTM', 'FTA', 'TOV', 'PF', 'ORB', 'DRB', 'REB',
       'AST', 'STL', 'BLK', 'PTS']]

# %%
# M

basket1.columns=['League', 'Season', 'Player', 'Team', 'GP', 'MIN', '2PM',
       '2PA', '3PM', '3PA', '1PM', '1PA', 'TOV', 'PF', 'ORB', 'DRB', 'REB',
       'AST', 'STL', 'BLK', 'PTS']

# %%
# Vamos a seleccionar ahora unicamente la NBA, ya que nuestro cliente pertenece a dicha liga.

basket2=basket1[basket1["League"]=="NBA"]

# %%
# Seleccionamos ahora las dos últimas temporadas.

basket3=basket2[basket2["Season"]=="2018 - 2019"]
basket4=basket2[basket2["Season"]=="2019 - 2020"]
basket5=pd.concat([basket4, basket3], axis=0)

# %%
# Seleccionamos ahora el equipo de nuestro cliente "Los Angeles Lakers" y al actual campeón de la NBA.

basket6=basket5[basket5["Team"]=="LAL"]
basket7=basket5[basket5["Team"]=="HOU"]
basket8=pd.concat([basket6, basket7], axis=0)

# %%
# Vamos a comprobar ahora que no tengamos filas duplicadas.

basket8.duplicated().sum()
# Out:
# 0

# %%
# No tenemos filas duplicadas, por lo que vamos a comprobar ahora si tenemos valores nulos.

basket8.isnull().sum()
# Out:
# League    0
# Season    0
# Player    0
# Team      0
# GP        0
# MIN       0
# 2PM       0
# 2PA       0
# 3PM       0
# 3PA       0
# 1PM       0
# 1PA       0
# TOV       0
# PF        0
# ORB       0
# DRB       0
# REB       0
# AST       0
# STL       0
# BLK       0
# PTS       0
# dtype: int64

# %%
# Vamos a utilizar la función regex para modificar los nombres de los equipos y hacerlos más entendibles.

basket8.Team=basket8.Team.str.replace(r" ?LAL ?", "Lakers")
basket8.Team=basket8.Team.str.replace(r" ?HOU ?", "Houston")

# %%
# Tampoco tenemos valores nulos, por lo que finalmente, está será la tabla que analizaremos.

basket8.reset_index()
# Out:
#     index League       Season                    Player     Team  GP     MIN  \
# 0   36957    NBA  2019 - 2020              LeBron James   Lakers  67  2316.3
# 1   36959    NBA  2019 - 2020             Anthony Davis   Lakers  62  2131.4
# 2   37047    NBA  2019 - 2020                Kyle Kuzma   Lakers  61  1526.2
# 3   37088    NBA  2019 - 2020  Kentavious Caldwell-Pope   Lakers  69  1761.8
# 4   37113    NBA  2019 - 2020           Markieff Morris   Lakers  58  1187.5
# 5   37117    NBA  2019 - 2020               Danny Green   Lakers  68  1686.7
# 6   37122    NBA  2019 - 2020             Dwight Howard   Lakers  69  1305.7
# 7   37151    NBA  2019 - 2020              JaVale McGee   Lakers  68  1130.1
# 8   37157    NBA  2019 - 2020             Avery Bradley   Lakers  49  1186.5
# 2   291   668   86  ...  155   91  126   52  221  273   80   28   26   782
# 3   237   507   92  ...  102   62  128   38  104  142  111   57   14   645
# 4   203   458   88  ...   85   76  133   40  178  218   77   31   17   560
# 5   197   474  120  ...   48   63  136   51  174  225   91   85   32   547
# 6   202   277    3  ...  214   84  222  172  335  507   45   31   79   517
# 7   195   306    3  ...   82   55  159  125  265  390   37   36   94   446
# 8   170   383   63  ...   24   47  110   18   97  115   63   43    5   423
# 9   120   291   40  ...   94   53   98   17  106  123  124   70   18   349
# 10  137   328   41  ...   41   91   58   23  119  142  240   40    2   342
# 11  558  1095  111  ...  418  197   94   57  408  465  454   72   33  1505
# 12  496  1087  128  ...  250  133  170   60  322  382  178   41   26  1308
# 13  362   729   31  ...  289  129  149   41  226  267  154   28   31   950
# 14  325   756  151  ...  158   65  137   48  190  238  110   73   13   938
# 15  400   641    1  ...  152  108  208  195  371  566   52   47  148   897
# 16  245   594  148  ...   85   65  109   22  151  173  129   40   12   711
# 17  189   464   92  ...   80   58  147   35  213  248   93   64   40   525
# 18  184   432   73  ...   73   86  111   32  183  215  140   41    7   491
# 19  185   456   75  ...   48  103  114   54  197  251  255   69   19   465
# 20  145   361   89  ...   85   48  130   57  187  244   76   22   38   449
# 21   61    99    0  ...   87   42  110   92  215  307   37   21   23   173
# 22  672  1514  299  ...  800  308  227   70  376  446  512  125   60  2335
# 23  604  1281   55  ...  380  255  200  100  351  451  401   93   20  1553
# 24  305   723  161  ...  124  103  220   63  400  463   88  114   94   870
# 25  242   545  181  ...   67   50  155   21  136  157   58   45   16   715
# 26  230   539  129  ...   90   54  132   57  210  267   85   67   34   662
# 27  211   501   96  ...  111   50  129   27  148  175  113   49   10   596
# 28  244   388    0  ...  104   63  102  168  369  537   48   33   72   543
# 29  177   426  107  ...   48   72  229  112  364  476  115   77   36   500
# 30  843  1909  378  ...  858  387  244   66  452  518  586  158   58  2818
# 31  474   732    0  ...  261   94  168  298  550  848   96   44  102  1114
# 32  384   938  216  ...  152   90  143   17  131  148  129   41   27  1103
# 33  302   720  127  ...  203  152  146   36  229  265  473  114   18   906
# 34  231   578  156  ...   68   55  126   30  152  182   40   33   27   675
# 35  232   572  104  ...   95   68  207   25  137  162  167   47   23   618
# 36  207   523  146  ...   59   63  252  121  358  479   96  132   39   601
# 37  167   446   95  ...   45   50  127   27  156  183  112   59   24   465
# 38   49   121   21  ...   22    8   32    9   45   54    5    4    7   134
# 39  109   264   48  ...   98   51   41    9   67   76   73   24   10   348
# 40   67   150   38  ...   28   27   22    5   22   27   14    7   11   196
# 41   66   148   17  ...   45   37   36   14   56   70   60   24    7   187
# 42   40    88   26  ...   23    8   35   19   63   82   19   19    8   125
# 43   46    82    0  ...   35   16   26   41   72  113   16    3   12   107
# 44   27    62   16  ...    6    8   31    2   19   21   10    5    1    74
# 45   12    40   10  ...    5    3   12    0   12   12    1    3    3    39
# 46   11    37    8  ...    8    4   11    2   20   22    1    3    2    34
# 47   10    26    8  ...    4    3   10    1   11   12    2    1    0    29
#
# [48 rows x 22 columns]

# %%
# Exportamos finalmente nuestra nueva tabla.

basket8.to_csv(r"./output/basket_analysis.csv", index = False)
